# %%
import numpy as np
import pandas as pd
import os

df = pd.read_csv('master3.csv')
df = df.dropna()

Y = df['Target']
X = df[['year','CDC Week','Count']]

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=.8, random_state = 584)

dtmodel = DecisionTreeClassifier()
dtmodel.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
# Predict on Year, CDC Week and Count
Y_pred = dtmodel.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.2777777777777778

# %%
df['Population'] = df['Population'].astype(float)
df['UnempRate'] = df['UnempRate'].astype(float)

Y = df['Target']
#X = df.drop(['Target','Unnamed: 0','Unnamed: 0.1','FIPS','County Centroid','Week Ending Date','County','GDP','GDP_change'], axis = 1)
X = df[['year','CDC Week','Count','flu']]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=.8, random_state = 584)

dtmodel = DecisionTreeClassifier()
dtmodel.fit(X_train,Y_train)

Y_pred = dtmodel.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.25157232704402516

# %%
Y = df['Target']
X = df.drop(['Target','Unnamed: 0','Unnamed: 0.1','FIPS','County Centroid','Week Ending Date','County','GDP','GDP_change'], axis = 1)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=.8, random_state = 584)

from sklearn.linear_model import LinearRegression
lrmodel = LinearRegression()
lrmodel.fit(X_train,Y_train)

Y_pred = lrmodel.predict(X_test)
print("R2 score:",metrics.r2_score(Y_test, Y_pred))
# Out:
# R2 score: 0.6272618635230893

# %%
Y = df['Target']
X = df[['year','CDC Week','Count']]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=.8, random_state = 584)

from sklearn.linear_model import LinearRegression
lrmodel = LinearRegression()
lrmodel.fit(X_train,Y_train)

Y_pred = lrmodel.predict(X_test)
print("R2 score:",metrics.r2_score(Y_test, Y_pred))
# Out:
# R2 score: 0.5400329363571074

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  County   FIPS            County Centroid  \
# 132           132           132  ALBANY  36001  (42.5882713, -73.9740136)
# 133           133           133  ALBANY  36001  (42.5882713, -73.9740136)
# 134           134           134  ALBANY  36001  (42.5882713, -73.9740136)
# 135           135           135  ALBANY  36001  (42.5882713, -73.9740136)
# 136           136           136  ALBANY  36001  (42.5882713, -73.9740136)
# 137           137           137  ALBANY  36001  (42.5882713, -73.9740136)
# 138           138           138  ALBANY  36001  (42.5882713, -73.9740136)
# 139           139           139  ALBANY  36001  (42.5882713, -73.9740136)
# 140           140           140  ALBANY  36001  (42.5882713, -73.9740136)
# 141           141           141  ALBANY  36001  (42.5882713, -73.9740136)
# 142           142           142  ALBANY  36001  (42.5882713, -73.9740136)
# 143           143           143  ALBANY  36001  (42.5882713, -73.9740136)
# ...
